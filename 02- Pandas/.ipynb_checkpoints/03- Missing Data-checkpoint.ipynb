# %% [markdown]
# # Missing Data

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn
np.random.seed (42)

# %%
df = pd.DataFrame(randn(10,3) ,columns = ['X','Y','Z'])

# %%
df
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264  0.647689
# 1  1.523030 -0.234153 -0.234137
# 2  1.579213  0.767435 -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304  1.465649
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
df < 0.6
# Out:
#        X      Y      Z
# 0   True   True  False
# 1  False   True   True
# 2  False  False   True
# 3   True   True   True
# 4   True   True   True
# 5   True   True   True
# 6   True   True  False
# 7   True   True   True
# 8   True   True   True
# 9   True   True   True

# %%
df1 = df [df < 0.6]

# %%
df1
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264       NaN
# 1       NaN -0.234153 -0.234137
# 2       NaN       NaN -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304       NaN
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
df1.shape
# Out:
# (10, 3)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       8 non-null      float64
#  1   Y       9 non-null      float64
#  2   Z       8 non-null      float64
# dtypes: float64(3)
# memory usage: 368.0 bytes

# %% [markdown]
# ### Drop Missing Values using `DataFrame.dropna()`

# %%
df1.dropna () # inplace = True
# Out:
#           X         Y         Z
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
df1
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264       NaN
# 1       NaN -0.234153 -0.234137
# 2       NaN       NaN -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304       NaN
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
df1.dropna(thresh = 2) #thresh : minimum number of null values in one row to be dropped
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264       NaN
# 1       NaN -0.234153 -0.234137
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304       NaN
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
# df1.dropna (axis=1)

# %% [markdown]
# ### Filling Null NAN with Values `DataFrame.fillna()`

# %%
df1
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264       NaN
# 1       NaN -0.234153 -0.234137
# 2       NaN       NaN -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304       NaN
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
df1.fillna (value=1)
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264  1.000000
# 1  1.000000 -0.234153 -0.234137
# 2  1.000000  1.000000 -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304  1.000000
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
df1
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264       NaN
# 1       NaN -0.234153 -0.234137
# 2       NaN       NaN -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304       NaN
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
print (df1['X'].fillna(value=1))
print (df1['Y'].fillna(value=2))
print (df1['Z'].fillna(value="Asem"))
# Out:
# 0    0.496714
# 1    1.000000
# 2    1.000000
# 3    0.542560
# 4    0.241962
# 5   -0.562288
# 6   -0.908024
# 7   -0.225776
# 8   -0.544383
# 9    0.375698
# Name: X, dtype: float64
# 0   -0.138264
# 1   -0.234153
# 2    2.000000
# 3   -0.463418
# 4   -1.913280
# 5   -1.012831
# 6   -1.412304
# 7    0.067528
# 8    0.110923
# 9   -0.600639
# Name: Y, dtype: float64
# 0        Asem
# 1   -0.234137
# 2   -0.469474
# 3    -0.46573
# 4   -1.724918
# 5    0.314247
# 6        Asem
# 7   -1.424748
# 8   -1.150994
# 9   -0.291694
# Name: Z, dtype: object

# %%
df1
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264       NaN
# 1       NaN -0.234153 -0.234137
# 2       NaN       NaN -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304       NaN
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694

# %%
df1['X'].mean()
# Out:
# -0.0729420179081248

# %%
df1['X'].fillna (value=df1['X'].mean() ,inplace=True)

# %%
df1
# Out:
#           X         Y         Z
# 0  0.496714 -0.138264       NaN
# 1 -0.072942 -0.234153 -0.234137
# 2 -0.072942       NaN -0.469474
# 3  0.542560 -0.463418 -0.465730
# 4  0.241962 -1.913280 -1.724918
# 5 -0.562288 -1.012831  0.314247
# 6 -0.908024 -1.412304       NaN
# 7 -0.225776  0.067528 -1.424748
# 8 -0.544383  0.110923 -1.150994
# 9  0.375698 -0.600639 -0.291694
